# %% [markdown]
# # Ablation C Llamarec
#
# Run this notebook after wiring the real pipeline on Day 3.
# Exports results to .

# %%
import json, httpx, sys
sys.path.insert(0, '..')
API_URL = 'http://localhost:8000'
client  = httpx.Client(base_url=API_URL, timeout=60.0)
print('API health:', client.get('/health').json())

# %% [markdown]
# ## TODO: implement ablation comparison cells here
#
# See PRD Section 5.3 for the required ablation structure.

# %%
# Save results
results = {'ablation': 'ablation_c_llamarec', 'status': 'TODO — implement'}
with open('../metrics/ablation_results.json', 'w') as f:
    json.dump(results, f, indent=2)
print('Saved ablation results')
